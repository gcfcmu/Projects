# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# https://covid19.who.int/data
# 3 methods: k-means, regression, HMMS (used to be naive bayes)

# %%
covid_global_df = pd.read_csv('../data/WHO-COVID-19-global-data.csv')

# %%
vacc_df = pd.read_csv('../data/vaccination-data.csv')

# %%
vacc_df.head(5)
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2023-04-18
# 1         Albania  ALB       EURO   REPORTING   2023-03-19
# 2         Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3  American Samoa  ASM       WPRO   REPORTING   2023-03-29
# 4         Andorra  AND       EURO   REPORTING   2023-02-26
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0          16826772.0                       14719397
# 1           3070468.0                        1347054
# 2          15267442.0                        7840131
# 3            114706.0                          46206
# 4            156957.0                          57904
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     43.225                                37.812
# 1                    106.700                                47.332
# 2                     34.817                                17.879
# 3                    207.812                                83.711
# 4                    203.100                                76.012
#
#    PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 0                  14005566                           35.978
# 1                   1276432                           44.851
# 2                   6481186                           14.780
# 3                     42479                           76.959
# 4                     53492                           70.221
#
#                                        VACCINES_USED FIRST_VACCINE_DATE  \
# 0  AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...         2021-02-22
# 1  AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-V...         2021-01-13
# 2  Beijing CNBG - BBIBP-CorV,Gamaleya - Gam-Covid...         2021-01-30
# 3  Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...         2020-12-21
# 4  AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...         2021-01-20
#
#    NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 0                        11.0                 1072990.0
# 1                         5.0                  395384.0
# 2                         4.0                  575651.0
# 3                         3.0                   24160.0
# 4                         3.0                   43060.0
#
#    PERSONS_BOOSTER_ADD_DOSE_PER100
# 0                            2.756
# 1                           13.893
# 2                            1.313
# 3                           43.770
# 4                           56.526

# %%
vacc_df.loc[vacc_df['COUNTRY'] == 'United States of America']
# Out:
#                       COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 219  United States of America  USA       AMRO   REPORTING   2023-04-07
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 219         666541020.0                      267141226
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 219                     201.37                                80.707
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 219                 227731485                           68.801
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 219  Janssen - Ad26.COV 2-S,Moderna - Spikevax,Nova...         2020-12-14
#
#      NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 219                         4.0               116145529.0
#
#      PERSONS_BOOSTER_ADD_DOSE_PER100
# 219                           35.089

# %%
covid_global_df.head(3)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0

# %%
covid_global_df.tail(3)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 285108    2023-04-17           ZW  Zimbabwe       AFRO          3
# 285109    2023-04-18           ZW  Zimbabwe       AFRO          0
# 285110    2023-04-19           ZW  Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 285108            264613           0               5684
# 285109            264613           0               5684
# 285110            264613           0               5684

# %%
covid_us_df = covid_global_df.loc[covid_global_df['Country'] == 'United States of America']
covid_us_df
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 271878    2020-01-03           US  United States of America       AMRO
# 271879    2020-01-04           US  United States of America       AMRO
# 271880    2020-01-05           US  United States of America       AMRO
# 271881    2020-01-06           US  United States of America       AMRO
# 271882    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 273076    2023-04-15           US  United States of America       AMRO
# 273077    2023-04-16           US  United States of America       AMRO
# 273078    2023-04-17           US  United States of America       AMRO
# 273079    2023-04-18           US  United States of America       AMRO
# 273080    2023-04-19           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 271878          0                 0           0                  0
# 271879          0                 0           0                  0
# 271880          0                 0           0                  0
# 271881          0                 0           0                  0
# 271882          0                 0           0                  0
# ...           ...               ...         ...                ...
# 273076          0         102977396           0            1120529
# 273077          0         102977396           0            1120529
# 273078          0         102977396           0            1120529
# 273079          0         102977396           0            1120529
# 273080          0         102977396           0            1120529
#
# [1203 rows x 8 columns]

# %%
vacc_df.loc[vacc_df['COUNTRY'] == 'United States of America']
# Out:
#                       COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 219  United States of America  USA       AMRO   REPORTING   2023-04-07
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 219         666541020.0                      267141226
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 219                     201.37                                80.707
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 219                 227731485                           68.801
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 219  Janssen - Ad26.COV 2-S,Moderna - Spikevax,Nova...         2020-12-14
#
#      NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 219                         4.0               116145529.0
#
#      PERSONS_BOOSTER_ADD_DOSE_PER100
# 219                           35.089

# %%
# get most_recent_date
most_recent_date = covid_global_df[['Date_reported']].max().iloc[0]

# %%
covid_global_mrd = covid_global_df.loc[covid_global_df['Date_reported'] == most_recent_date]
covid_global_mrd.head(3)
# Out:
#      Date_reported Country_code      Country WHO_region  New_cases  \
# 1202    2023-04-19           AF  Afghanistan       EMRO          0
# 2405    2023-04-19           AL      Albania       EURO          0
# 3608    2023-04-19           DZ      Algeria       AFRO          0
#
#       Cumulative_cases  New_deaths  Cumulative_deaths
# 1202            213191           0               7885
# 2405            333897           0               3604
# 3608            271644           0               6881

# %%
np.unique(covid_global_mrd[['WHO_region']])
# Out:
# array(['AFRO', 'AMRO', 'EMRO', 'EURO', 'Other', 'SEARO', 'WPRO'],
#       dtype=object)

# %%
sns.scatterplot(data=covid_global_mrd, x="Cumulative_cases", y="Cumulative_deaths", hue='WHO_region')
# Out:
# <AxesSubplot: xlabel='Cumulative_cases', ylabel='Cumulative_deaths'>

# %%
df.loc[df ['col1'] == value]
