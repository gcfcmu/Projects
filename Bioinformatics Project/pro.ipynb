# %%
import seaborn
import matplotlib.pyplot
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\splel\OneDrive\Desktop\Fourth Semester\Fundamentals of Bioinformatics\hic_3_3_df.csv")

# %%
df
# Out:
#                x          y      counts
# 0         190000     350000  115.487350
# 1         330000     350000  164.981918
# 2         340000     350000  115.487350
# 3         350000     350000  633.317688
# 4         350000     450000  288.718353
# ...          ...        ...         ...
# 890477  83150000  198070000    0.542046
# 890478  98180000  198070000    0.145150
# 890479  93470000  198080000    0.005229
# 890480  98220000  198080000    0.104630
# 890481  93470000  198120000    0.076450
#
# [890482 rows x 3 columns]

# %%
df
# Out:
#                x          y      counts
# 0         190000     350000  115.487350
# 1         330000     350000  164.981918
# 2         340000     350000  115.487350
# 3         350000     350000  633.317688
# 4         350000     450000  288.718353
# ...          ...        ...         ...
# 890477  83150000  198070000    0.542046
# 890478  98180000  198070000    0.145150
# 890479  93470000  198080000    0.005229
# 890480  98220000  198080000    0.104630
# 890481  93470000  198120000    0.076450
#
# [890482 rows x 3 columns]

# %%
t = pd.DataFrame({"x" : [0, 1, 2, 3], "y" : [0, 1, 2, 3], "counts" : [0.2, 0.3, 0.3, 0.4]})

# %%
df_pivot = df.pivot(index = "x", columns = "y", values = "counts")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 df_pivot = df.pivot(index = "x", columns = "y", values = "counts")
#
# File c:\Users\splel\anaconda3\lib\site-packages\pandas\core\frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7874     from pandas.core.reshape.pivot import pivot
# -> 7876     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\splel\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [25], in <cell line: 6>()
#       4 x = max(df["x"])
#       5 y = max(df["y"])
# ----> 6 X,Y = np.meshgrid(df["x"], df["y"])
#       8 plt.pcolormesh(X, Y, Z)
#
# File <__array_function__ internals>:5, in meshgrid(*args, **kwargs)
#
# File c:\Users\splel\anaconda3\lib\site-packages\numpy\lib\function_base.py:4373, in meshgrid(copy, sparse, indexing, *xi)
#    4370     output = np.broadcast_arrays(*output, subok=True)
#    4372 if copy:
# -> 4373     output = [x.copy() for x in output]
#    4375 return output
#
# File c:\Users\splel\anaconda3\lib\site-packages\numpy\lib\function_base.py:4373, in <listcomp>(.0)
#    4370     output = np.broadcast_arrays(*output, subok=True)
#    4372 if copy:
# -> 4373     output = [x.copy() for x in output]
#    4375 return output
#
# ...
