# %% [markdown]
# <a href="https://colab.research.google.com/github/gcfcmu/Projects/blob/main/Grad_project_final_code_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scanpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import scanpy

# %%
import pandas

# %%
import anndata

# %%
import os
os.getcwd()
# Out:
# '/Users/gabrielf/Downloads'

# %%
data2 = scanpy.read_10x_mtx("GEB/", gex_only = False)

# %%
meta = pandas.read_csv("GEB/metadata.csv")

l = []
for i in range(0,len(meta["cell_type__ontology_label"])):
    l.append(meta["cell_type__ontology_label"][i])
    
    
data2.obs["cell"] = l

s = []
for i in range(0, len(meta["disease__ontology_label"])):
    s.append(meta["disease__ontology_label"][i])




data2.obs["disease"] = s

# %%
scanpy.pp.neighbors(data2)

scanpy.tl.umap(data2)
# Out:
# WARNING: You’re trying to run this on 2868 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
scanpy.pl.umap(data2, color = "cell")

# %%
scanpy.tl.rank_genes_groups(data2,groupby="cell",method="logreg")
# Out:
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
result = data2.uns["rank_genes_groups"]

# %%
scanpy.pl.heatmap(data2, var_names = data2.var_names, groupby="cell", vmax = 30.0)
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`

# %%
scanpy.pl.heatmap(data2, var_names = data2.var_names, groupby="cell", log=True)
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`

# %%
display(data2.obsm["X_pca"])
# Out:
# array([[ 1.1380482e+02, -2.0313995e+02, -3.1184568e+01, ...,
#          7.4052529e+00, -1.3105872e+01,  1.8915382e+01],
#        [-3.7484988e+02,  6.7359985e+01,  1.9809253e+02, ...,
#          2.3500838e+00,  2.5334229e+00,  5.9308639e+00],
#        [-7.4797745e+01, -9.7426529e+01, -7.0811302e+01, ...,
#          1.9313495e+00, -3.8163822e+00, -8.6741433e-02],
#        ...,
#        [ 1.7562944e+02, -2.1123788e+02,  3.9878521e+01, ...,
#         -1.3113861e+01,  2.6347106e+00,  1.0706365e+01],
#        [-2.0901436e+02,  1.8875434e+00, -7.5622375e+01, ...,
#          6.8709689e-01,  2.0328732e+00, -5.3014046e-01],
#        [ 4.1030725e+02,  4.9333701e+00, -3.6383678e+01, ...,
#         -4.7010956e+00,  1.4171962e-02,  3.5491322e+01]], dtype=float32)

# %%
scanpy.tl.dendrogram(data2, groupby="cell")

# %%
scanpy.pl.dendrogram(data2, groupby="cell")
# Out:
# <AxesSubplot:>

# %%
scanpy.pl.pca(data2, color="cell")

# %%
scanpy.pl.stacked_violin(data2, var_names = data2.var_names[1:10],  groupby = "cell", figsize=(20,15))

# %%
scanpy.pl.stacked_violin(data2, var_names = "Clasp2",  groupby = "cell", figsize=(20,15))

# %%
scanpy.tl.rank_genes_groups(data2 ,groupby="cell", method="wilcoxon", group = "disease")

# %%
scanpy.pl.stacked_violin(data2, var_names = data2.var_names[1:10],  groupby = "disease", figsize = (20,15))

# %%
scanpy.tl.rank_genes_groups(data2, groupby="cell", group="disease")
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'

# %%
scanpy.pl.heatmap(data2, var_names = data2.var_names, groupby="disease", vmax = 30.0)
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`

# %%
scanpy.pl.heatmap(data2, var_names = data2.var_names, groupby="disease", log=True)
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`

# %%
scanpy.tl.rank_genes_groups(data2, groupby="disease", method='wilcoxon', key_added = "wilcoxon")
scanpy.pl.rank_genes_groups(data2, n_genes=25, sharey=False, key="wilcoxon")

# %%
scanpy.pl.stacked_violin(data2, var_names = "H2-D1",  groupby = "cell", figsize=(20,15))

# %%
scanpy.pl.stacked_violin(data2, var_names = "Cdk8",  groupby = "cell", figsize=(20,15))

# %%
neurons = data2[data2.obs['cell'] == 'neuron',:]
neurons.obs['disease'].value_counts()
scanpy.tl.rank_genes_groups(neurons, 'disease', method='wilcoxon', key_added = "wilcoxon")
scanpy.pl.rank_genes_groups(neurons, n_genes=25, sharey=False, key="wilcoxon")
# Out:
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
neurons = data2[data2.obs['cell'] == 'neuron',:]
neurons.obs['disease'].value_counts()
scanpy.tl.rank_genes_groups(neurons, 'disease', method='wilcoxon', key_added = "wilcoxon")
scanpy.pl.rank_genes_groups(neurons, n_genes=25, sharey=False, key="wilcoxon")

# %%
microglia = data2[data2.obs['cell'] == 'microglial cell',:]
microglia.obs['disease'].value_counts()
scanpy.tl.rank_genes_groups(microglia, 'disease', method='wilcoxon', key_added = "wilcoxon")
scanpy.pl.rank_genes_groups(microglia, n_genes=25, sharey=False, key="wilcoxon")
# Out:
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
opc = data2[data2.obs['cell'] == 'oligodendrocyte precursor cell',:]
opc.obs['disease'].value_counts()
scanpy.tl.rank_genes_groups(opc, 'disease', method='wilcoxon', key_added = "wilcoxon")
scanpy.pl.rank_genes_groups(opc, n_genes=25, sharey=False, key="wilcoxon")
# Out:
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
astrocyte = data2[data2.obs['cell'] == 'astrocyte',:]
opc.obs['disease'].value_counts()
scanpy.tl.rank_genes_groups(astrocyte, 'disease', method='wilcoxon', key_added = "wilcoxon")
scanpy.pl.rank_genes_groups(astrocyte, n_genes=25, sharey=False, key="wilcoxon")
# Out:
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /Users/gabrielf/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
